# %% [markdown]
# ## Introduction
# #### Datatset
# - This dataset is obtained from Kaggle: [Heart Failure Prediction Dataset](https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction)
#
# #### Context
# - Cardiovascular disease (CVDs) is the number one cause of death globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worldwide. Four out of five CVD deaths are due to heart attacks and strokes, and one-third of these deaths occur prematurely in people under 70 years of age. Heart failure is a common event caused by CVDs.
# - People with cardiovascular disease or who are at high cardiovascular risk (due to the presence of one or more risk factors such as hypertension, diabetes, hyperlipidaemia or already established disease) need early detection and management.
# - This dataset contains 11 features that can be used to predict possible heart disease.
# - Let's train a machine learning model to assist with diagnosing this disease.

# %% [markdown]
# ### Import Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost

from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

RANDOM_STATE = 55

# %% [markdown]
# ### Analyze the dataset for training

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
# since Sex, ChestPainType, RestingECG, ExerciseAngina, ST_Slope are categorical, we need to one-hot encode them
cat_variables = ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']

df = pd.get_dummies(data = df, prefix = cat_variables, columns = cat_variables)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                918 non-null    int64
#  1   RestingBP          918 non-null    int64
#  2   Cholesterol        918 non-null    int64
#  3   FastingBS          918 non-null    int64
#  4   MaxHR              918 non-null    int64
#  5   Oldpeak            918 non-null    float64
#  6   HeartDisease       918 non-null    int64
#  7   Sex_F              918 non-null    bool
#  8   Sex_M              918 non-null    bool
#  9   ChestPainType_ASY  918 non-null    bool
#  10  ChestPainType_ATA  918 non-null    bool
#  11  ChestPainType_NAP  918 non-null    bool
#  12  ChestPainType_TA   918 non-null    bool
#  13  RestingECG_LVH     918 non-null    bool
#  14  RestingECG_Normal  918 non-null    bool
#  15  RestingECG_ST      918 non-null    bool
#  16  ExerciseAngina_N   918 non-null    bool
#  17  ExerciseAngina_Y   918 non-null    bool
#  18  ST_Slope_Down      918 non-null    bool
#  19  ST_Slope_Flat      918 non-null    bool
#  20  ST_Slope_Up        918 non-null    bool
# dtypes: bool(14), float64(1), int64(6)
# memory usage: 62.9 KB

# %%
# storing all the features
features = [x for x in df.columns if x not in 'HeartDisease']

# %%
# no of features
print(len(features))
# Out:
# 20

# %%
# Splitting the dataset
X_train, X_val, y_train, y_val = train_test_split(df[features], df['HeartDisease'], train_size = 0.8, random_state = RANDOM_STATE)

# %%
print(f'Train samples:  {len(X_train)}')
print(f'Croos-validation Samples: {len(X_val)}')
# Out:
# Train samples:  734
# Croos-validation Samples: 184

# %% [markdown]
# ## Building the Models
# The Gradient Boosting model, called XGBoost. The boosting methods train several trees, but instead of them being uncorrelated to each other, now the trees are fit one after the other in order to minimize the error.
#
# The model has the same parameters as a decision tree, plus the learning rate.
# - The learning rate is the size of the step on the Gradient Descent method that the XGBoost uses internally to minimize the error on each train step.
#
# One interesting thing about the XGBoost is that during fitting, it can take in an evaluation dataset of the form `(X_val,y_val)`.
# - On each iteration, it measures the cost (or evaluation metric) on the evaluation datasets.
# - Once the cost (or metric) stops decreasing for a number of rounds (called early_stopping_rounds), the training will stop.
# - More iterations lead to more estimators, and more estimators can result in overfitting.
# - By stopping once the validation metric no longer improves, we can limit the number of estimators created, and reduce overfitting.

# %% [markdown]
# Note some of the `.fit()` parameters:
# - `eval_set = [(X_train_eval,y_train_eval)]`:Here we must pass a list to the eval_set, because you can have several different tuples of eval sets.
# - `early_stopping_rounds`: This parameter helps to stop the model training if its evaluation metric is no longer improving on the validation set. It's set to 10.
#   - The model keeps track of the round with the best performance (lowest evaluation metric).
#   - Each successive round's evaluation metric is compared to the best metric.  If the model goes 10 rounds where none have a better metric than the best one, then the model stops training.
#   - The model is returned at its last state when training terminated, not its state during the best round.  For example, if the model stops at round 26, but the best round was 16, the model's training state at round 26 is returned, not round 16.
#   - Note that this is different from returning the model's "best" state (from when the evaluation metric was the lowest).

# %%
xgb_model = XGBClassifier(n_estimators = 500, learning_rate = 0.1,verbosity = 1, random_state = RANDOM_STATE)
xgb_model.fit(X_train,y_train,
              eval_set = [(X_val,y_val)],
              verbose = True,
              )

# don't know why if i add early_stopping_rounds, it provides error
# Out:
# [0]	validation_0-logloss:0.63095
# [1]	validation_0-logloss:0.58777
# [2]	validation_0-logloss:0.54738
# [3]	validation_0-logloss:0.51576
# [4]	validation_0-logloss:0.48698
# [5]	validation_0-logloss:0.46494
# [6]	validation_0-logloss:0.44365
# [7]	validation_0-logloss:0.42847
# [8]	validation_0-logloss:0.41043
# [9]	validation_0-logloss:0.39867
# [10]	validation_0-logloss:0.38697
# [11]	validation_0-logloss:0.37606
# [12]	validation_0-logloss:0.36825
# [13]	validation_0-logloss:0.35851
# [14]	validation_0-logloss:0.35220
# [15]	validation_0-logloss:0.34593
# [16]	validation_0-logloss:0.34132
# [17]	validation_0-logloss:0.33401
# [18]	validation_0-logloss:0.32793
# [19]	validation_0-logloss:0.32270
# [20]	validation_0-logloss:0.32071
# [21]	validation_0-logloss:0.31820
# [22]	validation_0-logloss:0.31809
# [23]	validation_0-logloss:0.31676
# [24]	validation_0-logloss:0.31413
# [25]	validation_0-logloss:0.31394
# [26]	validation_0-logloss:0.31255
# [27]	validation_0-logloss:0.31147
# [28]	validation_0-logloss:0.31246
# [29]	validation_0-logloss:0.31238
# [30]	validation_0-logloss:0.31244
# [31]	validation_0-logloss:0.31308
# [32]	validation_0-logloss:0.31302
# [33]	validation_0-logloss:0.31481
# [34]	validation_0-logloss:0.31593
# [35]	validation_0-logloss:0.31690
# [36]	validation_0-logloss:0.31774
# [37]	validation_0-logloss:0.31673
# [38]	validation_0-logloss:0.31765
# [39]	validation_0-logloss:0.31945
# [40]	validation_0-logloss:0.32021
# [41]	validation_0-logloss:0.31834
# [42]	validation_0-logloss:0.31912
# [43]	validation_0-logloss:0.32017
# [44]	validation_0-logloss:0.31975
# [45]	validation_0-logloss:0.32071
# [46]	validation_0-logloss:0.32202
# [47]	validation_0-logloss:0.32262
# [48]	validation_0-logloss:0.32366
# [49]	validation_0-logloss:0.32516
# [50]	validation_0-logloss:0.32517
# [51]	validation_0-logloss:0.32741
# [52]	validation_0-logloss:0.32793
# [53]	validation_0-logloss:0.32720
# [54]	validation_0-logloss:0.32781
# [55]	validation_0-logloss:0.32810
# [56]	validation_0-logloss:0.32812
# [57]	validation_0-logloss:0.32790
# [58]	validation_0-logloss:0.32814
# [59]	validation_0-logloss:0.32777
# [60]	validation_0-logloss:0.32798
# [61]	validation_0-logloss:0.32748
# [62]	validation_0-logloss:0.32879
# [63]	validation_0-logloss:0.32890
# [64]	validation_0-logloss:0.32843
# [65]	validation_0-logloss:0.32976
# [66]	validation_0-logloss:0.33039
# [67]	validation_0-logloss:0.33049
# [68]	validation_0-logloss:0.32880
# [69]	validation_0-logloss:0.32813
# [70]	validation_0-logloss:0.32887
# [71]	validation_0-logloss:0.32922
# [72]	validation_0-logloss:0.32910
# [73]	validation_0-logloss:0.33071
# [74]	validation_0-logloss:0.33081
# [75]	validation_0-logloss:0.33114
# [76]	validation_0-logloss:0.33102
# [77]	validation_0-logloss:0.33069
# [78]	validation_0-logloss:0.33023
# [79]	validation_0-logloss:0.33163
# [80]	validation_0-logloss:0.33146
# [81]	validation_0-logloss:0.33155
# [82]	validation_0-logloss:0.33109
# [83]	validation_0-logloss:0.33112
# [84]	validation_0-logloss:0.33086
# [85]	validation_0-logloss:0.33084
# [86]	validation_0-logloss:0.33261
# [87]	validation_0-logloss:0.33291
# [88]	validation_0-logloss:0.33314
# [89]	validation_0-logloss:0.33405
# [90]	validation_0-logloss:0.33448
# [91]	validation_0-logloss:0.33490
# [92]	validation_0-logloss:0.33665
# [93]	validation_0-logloss:0.33731
# [94]	validation_0-logloss:0.33776
# [95]	validation_0-logloss:0.33788
# [96]	validation_0-logloss:0.33863
# [97]	validation_0-logloss:0.33871
# [98]	validation_0-logloss:0.33944
# [99]	validation_0-logloss:0.34007
# [100]	validation_0-logloss:0.34002
# [101]	validation_0-logloss:0.34018
# [102]	validation_0-logloss:0.34128
# [103]	validation_0-logloss:0.34279
# [104]	validation_0-logloss:0.34307
# [105]	validation_0-logloss:0.34338
# [106]	validation_0-logloss:0.34458
# [107]	validation_0-logloss:0.34579
# [108]	validation_0-logloss:0.34663
# [109]	validation_0-logloss:0.34703
# [110]	validation_0-logloss:0.34792
# [111]	validation_0-logloss:0.34840
# [112]	validation_0-logloss:0.34915
# [113]	validation_0-logloss:0.35029
# [114]	validation_0-logloss:0.35087
# [115]	validation_0-logloss:0.35182
# [116]	validation_0-logloss:0.35305
# [117]	validation_0-logloss:0.35273
# [118]	validation_0-logloss:0.35318
# [119]	validation_0-logloss:0.35389
# [120]	validation_0-logloss:0.35458
# [121]	validation_0-logloss:0.35583
# [122]	validation_0-logloss:0.35580
# [123]	validation_0-logloss:0.35684
# [124]	validation_0-logloss:0.35721
# [125]	validation_0-logloss:0.35835
# [126]	validation_0-logloss:0.35871
# [127]	validation_0-logloss:0.35857
# [128]	validation_0-logloss:0.35992
# [129]	validation_0-logloss:0.36203
# [130]	validation_0-logloss:0.36236
# [131]	validation_0-logloss:0.36355
# [132]	validation_0-logloss:0.36475
# [133]	validation_0-logloss:0.36531
# [134]	validation_0-logloss:0.36523
# [135]	validation_0-logloss:0.36555
# [136]	validation_0-logloss:0.36680
# [137]	validation_0-logloss:0.36713
# [138]	validation_0-logloss:0.36772
# [139]	validation_0-logloss:0.36830
# [140]	validation_0-logloss:0.36890
# [141]	validation_0-logloss:0.36982
# [142]	validation_0-logloss:0.37097
# [143]	validation_0-logloss:0.37135
# [144]	validation_0-logloss:0.37126
# [145]	validation_0-logloss:0.37068
# [146]	validation_0-logloss:0.37186
# [147]	validation_0-logloss:0.37145
# [148]	validation_0-logloss:0.37258
# [149]	validation_0-logloss:0.37394
# [150]	validation_0-logloss:0.37409
# [151]	validation_0-logloss:0.37412
# [152]	validation_0-logloss:0.37472
# [153]	validation_0-logloss:0.37506
# [154]	validation_0-logloss:0.37621
# [155]	validation_0-logloss:0.37636
# [156]	validation_0-logloss:0.37603
# [157]	validation_0-logloss:0.37643
# [158]	validation_0-logloss:0.37659
# [159]	validation_0-logloss:0.37690
# [160]	validation_0-logloss:0.37733
# [161]	validation_0-logloss:0.37879
# [162]	validation_0-logloss:0.37942
# [163]	validation_0-logloss:0.38019
# [164]	validation_0-logloss:0.37981
# [165]	validation_0-logloss:0.38032
# [166]	validation_0-logloss:0.38081
# [167]	validation_0-logloss:0.38059
# [168]	validation_0-logloss:0.38031
# [169]	validation_0-logloss:0.38121
# [170]	validation_0-logloss:0.38166
# [171]	validation_0-logloss:0.38248
# [172]	validation_0-logloss:0.38308
# [173]	validation_0-logloss:0.38242
# [174]	validation_0-logloss:0.38259
# [175]	validation_0-logloss:0.38217
# [176]	validation_0-logloss:0.38276
# [177]	validation_0-logloss:0.38345
# [178]	validation_0-logloss:0.38295
# [179]	validation_0-logloss:0.38331
# [180]	validation_0-logloss:0.38441
# [181]	validation_0-logloss:0.38414
# [182]	validation_0-logloss:0.38571
# [183]	validation_0-logloss:0.38586
# [184]	validation_0-logloss:0.38634
# [185]	validation_0-logloss:0.38636
# [186]	validation_0-logloss:0.38633
# [187]	validation_0-logloss:0.38695
# [188]	validation_0-logloss:0.38819
# [189]	validation_0-logloss:0.38799
# [190]	validation_0-logloss:0.38845
# [191]	validation_0-logloss:0.38879
# [192]	validation_0-logloss:0.38942
# [193]	validation_0-logloss:0.38948
# [194]	validation_0-logloss:0.39016
# [195]	validation_0-logloss:0.39071
# [196]	validation_0-logloss:0.39146
# [197]	validation_0-logloss:0.39175
# [198]	validation_0-logloss:0.39207
# [199]	validation_0-logloss:0.39174
# [200]	validation_0-logloss:0.39294
# [201]	validation_0-logloss:0.39316
# [202]	validation_0-logloss:0.39364
# [203]	validation_0-logloss:0.39393
# [204]	validation_0-logloss:0.39422
# [205]	validation_0-logloss:0.39413
# [206]	validation_0-logloss:0.39453
# [207]	validation_0-logloss:0.39458
# [208]	validation_0-logloss:0.39512
# [209]	validation_0-logloss:0.39600
# [210]	validation_0-logloss:0.39685
# [211]	validation_0-logloss:0.39798
# [212]	validation_0-logloss:0.39798
# [213]	validation_0-logloss:0.39851
# [214]	validation_0-logloss:0.39927
# [215]	validation_0-logloss:0.39931
# [216]	validation_0-logloss:0.39966
# [217]	validation_0-logloss:0.40026
# [218]	validation_0-logloss:0.40040
# [219]	validation_0-logloss:0.40149
# [220]	validation_0-logloss:0.40197
# [221]	validation_0-logloss:0.40285
# [222]	validation_0-logloss:0.40339
# [223]	validation_0-logloss:0.40429
# [224]	validation_0-logloss:0.40482
# [225]	validation_0-logloss:0.40444
# [226]	validation_0-logloss:0.40567
# [227]	validation_0-logloss:0.40596
# [228]	validation_0-logloss:0.40590
# [229]	validation_0-logloss:0.40662
# [230]	validation_0-logloss:0.40664
# [231]	validation_0-logloss:0.40731
# [232]	validation_0-logloss:0.40725
# [233]	validation_0-logloss:0.40730
# [234]	validation_0-logloss:0.40743
# [235]	validation_0-logloss:0.40756
# [236]	validation_0-logloss:0.40758
# [237]	validation_0-logloss:0.40800
# [238]	validation_0-logloss:0.40780
# [239]	validation_0-logloss:0.40784
# [240]	validation_0-logloss:0.40814
# [241]	validation_0-logloss:0.40854
# [242]	validation_0-logloss:0.40926
# [243]	validation_0-logloss:0.40976
# [244]	validation_0-logloss:0.40957
# [245]	validation_0-logloss:0.40937
# [246]	validation_0-logloss:0.40946
# [247]	validation_0-logloss:0.40985
# [248]	validation_0-logloss:0.40996
# [249]	validation_0-logloss:0.41011
# [250]	validation_0-logloss:0.41093
# [251]	validation_0-logloss:0.41079
# [252]	validation_0-logloss:0.41138
# [253]	validation_0-logloss:0.41200
# [254]	validation_0-logloss:0.41226
# [255]	validation_0-logloss:0.41227
# [256]	validation_0-logloss:0.41269
# [257]	validation_0-logloss:0.41315
# [258]	validation_0-logloss:0.41384
# [259]	validation_0-logloss:0.41438
# [260]	validation_0-logloss:0.41517
# [261]	validation_0-logloss:0.41578
# [262]	validation_0-logloss:0.41584
# [263]	validation_0-logloss:0.41645
# [264]	validation_0-logloss:0.41650
# [265]	validation_0-logloss:0.41659
# [266]	validation_0-logloss:0.41627
# [267]	validation_0-logloss:0.41658
# [268]	validation_0-logloss:0.41719
# [269]	validation_0-logloss:0.41709
# [270]	validation_0-logloss:0.41783
# [271]	validation_0-logloss:0.41752
# [272]	validation_0-logloss:0.41807
# [273]	validation_0-logloss:0.41813
# [274]	validation_0-logloss:0.41859
# [275]	validation_0-logloss:0.41898
# [276]	validation_0-logloss:0.41957
# [277]	validation_0-logloss:0.42006
# [278]	validation_0-logloss:0.42056
# [279]	validation_0-logloss:0.42080
# [280]	validation_0-logloss:0.42148
# [281]	validation_0-logloss:0.42155
# [282]	validation_0-logloss:0.42199
# [283]	validation_0-logloss:0.42165
# [284]	validation_0-logloss:0.42168
# [285]	validation_0-logloss:0.42219
# [286]	validation_0-logloss:0.42286
# [287]	validation_0-logloss:0.42277
# [288]	validation_0-logloss:0.42311
# [289]	validation_0-logloss:0.42310
# [290]	validation_0-logloss:0.42367
# [291]	validation_0-logloss:0.42396
# [292]	validation_0-logloss:0.42429
# [293]	validation_0-logloss:0.42424
# [294]	validation_0-logloss:0.42481
# [295]	validation_0-logloss:0.42512
# [296]	validation_0-logloss:0.42501
# [297]	validation_0-logloss:0.42494
# [298]	validation_0-logloss:0.42524
# [299]	validation_0-logloss:0.42521
# [300]	validation_0-logloss:0.42489
# [301]	validation_0-logloss:0.42456
# [302]	validation_0-logloss:0.42481
# [303]	validation_0-logloss:0.42511
# [304]	validation_0-logloss:0.42550
# [305]	validation_0-logloss:0.42600
# [306]	validation_0-logloss:0.42604
# [307]	validation_0-logloss:0.42664
# [308]	validation_0-logloss:0.42679
# [309]	validation_0-logloss:0.42639
# [310]	validation_0-logloss:0.42648
# [311]	validation_0-logloss:0.42697
# [312]	validation_0-logloss:0.42693
# [313]	validation_0-logloss:0.42649
# [314]	validation_0-logloss:0.42643
# [315]	validation_0-logloss:0.42701
# [316]	validation_0-logloss:0.42740
# [317]	validation_0-logloss:0.42779
# [318]	validation_0-logloss:0.42823
# [319]	validation_0-logloss:0.42851
# [320]	validation_0-logloss:0.42846
# [321]	validation_0-logloss:0.42845
# [322]	validation_0-logloss:0.42877
# [323]	validation_0-logloss:0.42843
# [324]	validation_0-logloss:0.42832
# [325]	validation_0-logloss:0.42873
# [326]	validation_0-logloss:0.42899
# [327]	validation_0-logloss:0.42911
# [328]	validation_0-logloss:0.42909
# [329]	validation_0-logloss:0.42918
# [330]	validation_0-logloss:0.42978
# [331]	validation_0-logloss:0.43022
# [332]	validation_0-logloss:0.42993
# [333]	validation_0-logloss:0.42953
# [334]	validation_0-logloss:0.43008
# [335]	validation_0-logloss:0.43002
# [336]	validation_0-logloss:0.43034
# [337]	validation_0-logloss:0.43098
# [338]	validation_0-logloss:0.43123
# [339]	validation_0-logloss:0.43161
# [340]	validation_0-logloss:0.43187
# [341]	validation_0-logloss:0.43169
# [342]	validation_0-logloss:0.43195
# [343]	validation_0-logloss:0.43234
# [344]	validation_0-logloss:0.43187
# [345]	validation_0-logloss:0.43198
# [346]	validation_0-logloss:0.43144
# [347]	validation_0-logloss:0.43164
# [348]	validation_0-logloss:0.43165
# [349]	validation_0-logloss:0.43239
# [350]	validation_0-logloss:0.43259
# [351]	validation_0-logloss:0.43280
# [352]	validation_0-logloss:0.43276
# [353]	validation_0-logloss:0.43303
# [354]	validation_0-logloss:0.43281
# [355]	validation_0-logloss:0.43288
# [356]	validation_0-logloss:0.43344
# [357]	validation_0-logloss:0.43363
# [358]	validation_0-logloss:0.43421
# [359]	validation_0-logloss:0.43462
# [360]	validation_0-logloss:0.43452
# [361]	validation_0-logloss:0.43469
# [362]	validation_0-logloss:0.43475
# [363]	validation_0-logloss:0.43502
# [364]	validation_0-logloss:0.43541
# [365]	validation_0-logloss:0.43523
# [366]	validation_0-logloss:0.43603
# [367]	validation_0-logloss:0.43644
# [368]	validation_0-logloss:0.43652
# [369]	validation_0-logloss:0.43635
# [370]	validation_0-logloss:0.43627
# [371]	validation_0-logloss:0.43644
# [372]	validation_0-logloss:0.43617
# [373]	validation_0-logloss:0.43621
# [374]	validation_0-logloss:0.43625
# [375]	validation_0-logloss:0.43681
# [376]	validation_0-logloss:0.43676
# [377]	validation_0-logloss:0.43684
# [378]	validation_0-logloss:0.43710
# [379]	validation_0-logloss:0.43713
# [380]	validation_0-logloss:0.43731
# [381]	validation_0-logloss:0.43678
# [382]	validation_0-logloss:0.43673
# [383]	validation_0-logloss:0.43717
# [384]	validation_0-logloss:0.43716
# [385]	validation_0-logloss:0.43771
# [386]	validation_0-logloss:0.43758
# [387]	validation_0-logloss:0.43806
# [388]	validation_0-logloss:0.43815
# [389]	validation_0-logloss:0.43870
# [390]	validation_0-logloss:0.43882
# [391]	validation_0-logloss:0.43829
# [392]	validation_0-logloss:0.43853
# [393]	validation_0-logloss:0.43861
# [394]	validation_0-logloss:0.43872
# [395]	validation_0-logloss:0.43869
# [396]	validation_0-logloss:0.43870
# [397]	validation_0-logloss:0.43901
# [398]	validation_0-logloss:0.43929
# [399]	validation_0-logloss:0.43981
# [400]	validation_0-logloss:0.43995
# [401]	validation_0-logloss:0.43948
# [402]	validation_0-logloss:0.43949
# [403]	validation_0-logloss:0.43939
# [404]	validation_0-logloss:0.43986
# [405]	validation_0-logloss:0.43981
# [406]	validation_0-logloss:0.44025
# [407]	validation_0-logloss:0.44037
# [408]	validation_0-logloss:0.44084
# [409]	validation_0-logloss:0.44106
# [410]	validation_0-logloss:0.44119
# [411]	validation_0-logloss:0.44103
# [412]	validation_0-logloss:0.44101
# [413]	validation_0-logloss:0.44164
# [414]	validation_0-logloss:0.44189
# [415]	validation_0-logloss:0.44224
# [416]	validation_0-logloss:0.44225
# [417]	validation_0-logloss:0.44250
# [418]	validation_0-logloss:0.44227
# [419]	validation_0-logloss:0.44183
# [420]	validation_0-logloss:0.44197
# [421]	validation_0-logloss:0.44211
# [422]	validation_0-logloss:0.44246
# [423]	validation_0-logloss:0.44232
# [424]	validation_0-logloss:0.44256
# [425]	validation_0-logloss:0.44266
# [426]	validation_0-logloss:0.44258
# [427]	validation_0-logloss:0.44315
# [428]	validation_0-logloss:0.44355
# [429]	validation_0-logloss:0.44325
# [430]	validation_0-logloss:0.44337
# [431]	validation_0-logloss:0.44325
# [432]	validation_0-logloss:0.44298
# [433]	validation_0-logloss:0.44355
# [434]	validation_0-logloss:0.44357
# [435]	validation_0-logloss:0.44342
# [436]	validation_0-logloss:0.44377
# [437]	validation_0-logloss:0.44371
# [438]	validation_0-logloss:0.44427
# [439]	validation_0-logloss:0.44418
# [440]	validation_0-logloss:0.44431
# [441]	validation_0-logloss:0.44430
# [442]	validation_0-logloss:0.44436
# [443]	validation_0-logloss:0.44419
# [444]	validation_0-logloss:0.44427
# [445]	validation_0-logloss:0.44437
# [446]	validation_0-logloss:0.44481
# [447]	validation_0-logloss:0.44503
# [448]	validation_0-logloss:0.44515
# [449]	validation_0-logloss:0.44531
# [450]	validation_0-logloss:0.44523
# [451]	validation_0-logloss:0.44569
# [452]	validation_0-logloss:0.44600
# [453]	validation_0-logloss:0.44615
# [454]	validation_0-logloss:0.44659
# [455]	validation_0-logloss:0.44680
# [456]	validation_0-logloss:0.44711
# [457]	validation_0-logloss:0.44696
# [458]	validation_0-logloss:0.44658
# [459]	validation_0-logloss:0.44699
# [460]	validation_0-logloss:0.44719
# [461]	validation_0-logloss:0.44680
# [462]	validation_0-logloss:0.44678
# [463]	validation_0-logloss:0.44715
# [464]	validation_0-logloss:0.44705
# [465]	validation_0-logloss:0.44699
# [466]	validation_0-logloss:0.44661
# [467]	validation_0-logloss:0.44699
# [468]	validation_0-logloss:0.44716
# [469]	validation_0-logloss:0.44727
# [470]	validation_0-logloss:0.44752
# [471]	validation_0-logloss:0.44755
# [472]	validation_0-logloss:0.44754
# [473]	validation_0-logloss:0.44779
# [474]	validation_0-logloss:0.44806
# [475]	validation_0-logloss:0.44808
# [476]	validation_0-logloss:0.44822
# [477]	validation_0-logloss:0.44845
# [478]	validation_0-logloss:0.44873
# [479]	validation_0-logloss:0.44856
# [480]	validation_0-logloss:0.44886
# [481]	validation_0-logloss:0.44881
# [482]	validation_0-logloss:0.44893
# [483]	validation_0-logloss:0.44865
# [484]	validation_0-logloss:0.44882
# [485]	validation_0-logloss:0.44835
# [486]	validation_0-logloss:0.44835
# [487]	validation_0-logloss:0.44828
# [488]	validation_0-logloss:0.44822
# [489]	validation_0-logloss:0.44786
# [490]	validation_0-logloss:0.44794
# [491]	validation_0-logloss:0.44814
# [492]	validation_0-logloss:0.44818
# [493]	validation_0-logloss:0.44823
# [494]	validation_0-logloss:0.44818
# [495]	validation_0-logloss:0.44821
# [496]	validation_0-logloss:0.44851
# [497]	validation_0-logloss:0.44842
# [498]	validation_0-logloss:0.44849
# [499]	validation_0-logloss:0.44871
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, random_state=55, ...)

# %%
print(f"Metrics train:\n\tAccuracy score: {accuracy_score(xgb_model.predict(X_train),y_train):.4f}\nMetrics test:\n\tAccuracy score: {accuracy_score(xgb_model.predict(X_val),y_val):.4f}")
# Out:
# Metrics train:
# 	Accuracy score: 1.0000
# Metrics test:
# 	Accuracy score: 0.8804
